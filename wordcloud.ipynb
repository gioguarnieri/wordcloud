# %% [markdown]
# # Code to make a word cloud image from a txt file
#
# Author: Giovanni Guarnieri Soares
#
# An example is given below, using a txt file where each line is an article's title.

# %%
# !pip install wordcloud matplotlib # installing modules, if not necessary, remove or comment the cell
# Out:
# ...
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/34/ac/72a4e42e76bf549dfd91791a6b10a9832f046c1d48b5e778be9ec012aa47/wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/151.4 kB ? eta -:--:--
#    ---------------------------------------- 151.4/151.4 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS

# %%
wc_file = open('nuvem.txt', 'r') # opening the file
Lines = wc_file.readlines() # reading each line
Lines = [line.strip() for line in Lines] # removing the "\n" from each line
text = " ".join(i for i in Lines) # joining all lines to one string only

# %%
stopwords = set(STOPWORDS) # words to be ignored, such as "and", "a", "your", you can add your own words as follows
# stopwords = set(["words", "you", "want", "to", "remove"] + list(STOPWORDS)) # if you want to add yours, change the lines
wordcloud = WordCloud(stopwords=stopwords, width=3200, height=1600).generate(text) # generating the wordcloud, with a higher width and height we have better definition
plt.figure(figsize=(15,10)) # the size of the output figure
plt.imshow(wordcloud) # the wordcloud is generated as a matrix
plt.axis("off") # removing both axis
plt.tight_layout(pad=0) # removing borders
plt.savefig('wordcloud.png', transparent = True) # saving the file, you can change the name "wordcloud" and extension from png to pdf, if you want better resolution.
plt.show() # showing the figure

#this cell takes about 5~10s to run
